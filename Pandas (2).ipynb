# %%
#-------------------------------------------------------------------------------------------------------#
#                                               FAKHR BASHA                                             #   
#-------------------------------------------------------------------------------------------------------#
import pandas as pd

# %%
lst = [1,2,3,4]
s = pd.Series(lst)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# change DT
lst = [1,2,3,4]
s = pd.Series(lst , dtype = float)
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
# change idx
lst = [1,2,3,4]
s = pd.Series(lst , dtype = float , index = ["A","B","C","E"])
s
# Out:
# A    1.0
# B    2.0
# C    3.0
# E    4.0
# dtype: float64

# %%
# concate
x= pd.Series(["ahmed","salah"])
y= pd.Series(["mo","fakhr"])

z = pd.concat([x,y] , ignore_index = True ) #new idx
z
# Out:
# 0    ahmed
# 1    salah
# 2       mo
# 3    fakhr
# dtype: object

# %%
#Delete
s = pd.Series({10:'A',20:'B',30:'C',40:'D'}) # delete C
s
# Out:
# 10    A
# 20    B
# 30    C
# 40    D
# dtype: object

# %%
z = s.drop(30)
z
# Out:
# 10    A
# 20    B
# 40    D
# dtype: object

# %%
# Drop Duplicate
s = pd.Series({10:'A',20:'B',30:'C',40:'D',50:'B'})
s
# Out:
# 10    A
# 20    B
# 30    C
# 40    D
# 50    B
# dtype: object

# %%
z = s.drop_duplicates()
z
# Out:
# 10    A
# 20    B
# 30    C
# 40    D
# dtype: object

# %%
# copy
s = pd.Series([1,2,3])
s2 = s.copy()
s2
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s2.drop(0,inplace = True)
s2
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
#math Series
x = pd.Series([1,2,3,4,5])
z = x.add(5) # add 5 => 1 + 5 = 6 etc
z
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
l = z.sub(5)
l
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
l.mul(2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
l.div(2)
# Out:
# 0    0.5
# 1    1.0
# 2    1.5
# 3    2.0
# 4    2.5
# dtype: float64

# %%
# DataFrame
data = {
    'StudentName' : ['ahmed','mohamed','salah','Ali'],
    'studentgrade' : ['A+','B','C+','D']
} 
student = pd.DataFrame(data )
student
# Out:
#   StudentName studentgrade
# 0       ahmed           A+
# 1     mohamed            B
# 2       salah           C+
# 3         Ali            D

# %%
# create file CSV
#read
#student = pd.read_csv('path.csv)

# %%
cusromer = pd.read_csv('customers-100.csv')

customer
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
customer.head(3)
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
# 2      3  6F94879bDAfE5a6        Roy     Berry    Murillo-Perry
#
#                 City              Country          Phone 1  \
# 0       East Leonard                Chile     229.077.5154
# 1  East Jimmychester             Djibouti       5153435776
# 2      Isabelborough  Antigua and Barbuda  +1-539-402-0259
#
#                Phone 2                     Email Subscription Date  \
# 0     397.884.0519x718  zunigavanessa@smith.info        2020-08-24
# 1     686-620-1820x944           vmata@colon.com        2021-04-23
# 2  (496)978-3969x58947       beckycarr@hogan.com        2020-03-25
#
#                       Website
# 0  http://www.stephenson.com/
# 1       http://www.hobbs.com/
# 2    http://www.lawrence.com/

# %%
customer.tail(3)
# Out:
#     Index      Customer Id First Name Last Name             Company  \
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra       Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer  Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes  Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 97   +1-632-666-7507x92121                swagner@kane.org        2021-09-18
# 98  001-869-452-0943x12424  mccarthystephen@horn-green.biz        2021-08-11
# 99            783.639.1472          colleen91@faulkner.biz        2020-03-11
#
#                               Website
# 97              https://www.ross.com/
# 98               http://watkins.info/
# ...

# %%
s = customer[['City','Email']].groupby('City').max()
s
# Out:
#                                               Email
# City
# Acevedoville                     wterrell@clark.com
# Bensonview              stanleyblackwell@benson.org
# Brittanyview             rsingleton@ryan-cherry.com
# Bryanville                      mariah88@santos.com
# Burchbury         cassieparrish@blevins-chapman.net
# ...                                             ...
# West Marthaburgh     willistonya@randolph-baker.com
# West Priscilla              colinalvarado@miles.net
# West Reginald          mchandler@cochran-huerta.org
# West Samuel              gfigueroa@boone-zavala.com
# Zimmermanland                  bauercrystal@gay.com
#
# [100 rows x 1 columns]

# %%
customer.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
customer.describe(include=[object])
# Out:
#             Customer Id First Name Last Name    Company       City  \
# count               100        100       100        100        100
# unique              100         93        97         99        100
# top     2354a0E336A91A1     Joanna     Greer  Simon LLC  Judymouth
# freq                  1          2         2          2          1
#
#                 Country        Phone 1       Phone 2                   Email  \
# count               100            100           100                     100
# unique               85            100           100                     100
# top     Solomon Islands  (753)813-6941  783.639.1472  colleen91@faulkner.biz
# freq                  4              1             1                       1
#
#        Subscription Date                            Website
# count                100                                100
# unique                96                                100
# top           2021-04-23  http://www.hatfield-saunders.net/
# ...

# %%
customer[['Email','City']].head(10)
# Out:
#                          Email               City
# 0     zunigavanessa@smith.info       East Leonard
# 1              vmata@colon.com  East Jimmychester
# 2          beckycarr@hogan.com      Isabelborough
# 3  stanleyblackwell@benson.org         Bensonview
# 4      colinalvarado@miles.net     West Priscilla
# 5          louis27@gilbert.com      Chavezborough
# 6          tgates@cantrell.com           Lake Ana
# 7              asnow@colon.com            Kimport
# 8      mariokhan@ryan-pope.org       Robersonstad
# 9            mdyer@escobar.net         Elaineberg

# %%
customer[2:7]
# Out:
#    Index      Customer Id First Name Last Name  \
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
# 5      6  2d08FB17EE273F4      Aimee     Downs
# 6      7  EA4d384DfDbBf77     Darren      Peck
#
#                            Company            City  \
# 2                    Murillo-Perry   Isabelborough
# 3  Dominguez, Mcmillan and Donovan      Bensonview
# 4         Martin, Lang and Andrade  West Priscilla
# 5                     Steele Group   Chavezborough
# 6     Lester, Woodard and Mitchell        Lake Ana
#
#                       Country                 Phone 1                Phone 2  \
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# 3          Dominican Republic  001-808-617-6467x12895        +1-813-324-8756
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146  001-199-446-3860x3486
# ...

# %%
customer.loc[1:5 , ['City','Email','First Name']]
# Out:
#                 City                        Email First Name
# 1  East Jimmychester              vmata@colon.com    Preston
# 2      Isabelborough          beckycarr@hogan.com        Roy
# 3         Bensonview  stanleyblackwell@benson.org      Linda
# 4     West Priscilla      colinalvarado@miles.net     Joanna
# 5      Chavezborough          louis27@gilbert.com      Aimee

# %%
customer.sample(5)
# Out:
#     Index      Customer Id First Name Last Name                     Company  \
# 91     92  98b3aeDcC3B9FF3      Shane     Foley                  Rocha-Hart
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra               Schmitt-Jones
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter             Rasmussen Group
# 89     90  37Ec4B395641c1E       Lori   Flowers             Decker-Mcknight
# 84     85  03A1E62ADdeb31c      Corey      Holt  Mcdonald, Bird and Ramirez
#
#                 City          Country                Phone 1  \
# 91  South Dannymouth          Hungary        +1-822-569-0302
# 97        Ortegaland  Solomon Islands   +1-753-067-8419x7170
# 0       East Leonard            Chile           229.077.5154
# 89    North Joeburgh          Namibia           679.415.1210
# 84        New Glenda             Fiji  001-439-242-4986x7918
#
#                    Phone 2                     Email Subscription Date  \
# ...

# %%
customer.sample(5 , random_state=23) # keep random value
# Out:
#     Index      Customer Id First Name Last Name                     Company  \
# 26     27  aBdfcF2c50b0bfD     Dakota     Poole               Simmons Group
# 80     81  D6CEAfb3BDbaa1A     Leslie  Jennings           Blankenship-Arias
# 82     83  E8E7e8Cfe516ef0     Hunter    Moreno        Fitzpatrick-Lawrence
# 68     69  421a109cABDf5fa   Virginia    Dudley                  Warren Ltd
# 77     78  FfaeFFbbbf280db    Cassidy   Mcmahon  Mcguire, Huynh and Hopkins
#
#                   City                      Country             Phone 1  \
# 26        Michealshire                      Belarus  (371)987-8576x4720
# 80           Coreybury                   Micronesia        629.198.6346
# 82        East Clinton                  Isle of Man       (733)833-6754
# 68            Hartbury  French Southern Territories  027.846.3705x14184
# 77  Lake Sherryborough                      Myanmar          5040771311
#
#                  Phone 2                       Email Subscription Date  \
# ...

# %%
customer[customer['City'] == 'Coreybury'] #filter
# Out:
#     Index      Customer Id First Name Last Name            Company       City  \
# 80     81  D6CEAfb3BDbaa1A     Leslie  Jennings  Blankenship-Arias  Coreybury
#
#        Country       Phone 1       Phone 2                Email  \
# 80  Micronesia  629.198.6346  075.256.0829  corey75@wiggins.com
#
#    Subscription Date                  Website
# 80        2021-11-13  https://www.juarez.com/

# %%
customer.isnull() # fliter missing value
# Out:
#     Index  Customer Id  First Name  Last Name  Company   City  Country  \
# 0   False        False       False      False    False  False    False
# 1   False        False       False      False    False  False    False
# 2   False        False       False      False    False  False    False
# 3   False        False       False      False    False  False    False
# 4   False        False       False      False    False  False    False
# ..    ...          ...         ...        ...      ...    ...      ...
# 95  False        False       False      False    False  False    False
# 96  False        False       False      False    False  False    False
# 97  False        False       False      False    False  False    False
# 98  False        False       False      False    False  False    False
# 99  False        False       False      False    False  False    False
#
#     Phone 1  Phone 2  Email  Subscription Date  Website
# 0     False    False  False              False    False
# ...

# %%
# Data Manipulating
#aggfunction max() min() sum()

# %%
customer['Subscription Date'].max()
# Out:
# '2022-05-26'

# %%
customer['Subscription Date'].min()
# Out:
# '2020-01-13'

# %%
# delete column(axis=1) or row (axis=0)
customer.drop('Phone 2' , axis=1,inplace=True)

# %%
customer
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# delete row
customer.drop(5,axis=0,inplace=True)

# %%
customer
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
#----------------------------------------------Fakhr Basha--------------------------------------------------
