# %%
#-------------------------------------------------------------------------------------------------------#
#                                               FAKHR BASHA                                             #   
#-------------------------------------------------------------------------------------------------------#

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('aa.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4969 entries, 0 to 4968
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4969 non-null   int64
#  1   imdb_id               4962 non-null   object
#  2   popularity            4969 non-null   float64
#  3   budget                4969 non-null   int64
#  4   revenue               4969 non-null   int64
#  5   original_title        4969 non-null   object
#  6   cast                  4919 non-null   object
#  7   homepage              1998 non-null   object
#  8   director              4937 non-null   object
#  9   tagline               3492 non-null   object
#  10  keywords              4069 non-null   object
#  11  overview              4965 non-null   object
#  12  runtime               4969 non-null   int64
#  13  genres                4956 non-null   object
#  14  production_companies  4433 non-null   object
# ...

# %%
# histogram chart
x = np.random.randn(500)
plt.hist(x)
# Out:
# (array([  2.,   2.,  14.,  63., 111., 151.,  95.,  47.,  12.,   3.]),
#  array([-3.93267225, -3.20116432, -2.46965639, -1.73814846, -1.00664052,
#         -0.27513259,  0.45637534,  1.18788327,  1.91939121,  2.65089914,
#          3.38240707]),
#  <BarContainer object of 10 artists>)

# %%
# delete element array and keep histogram use ;
plt.hist(x);
plt.show();

# %%
plt.hist(x,5);

# %%
# use ifile csv
plt.hist(df["vote_average"]);

# %%
df["vote_average"].max()
# Out:
# 9.2

# %%
bins_num = [0,2,4,6,8,10];
plt.hist(df["vote_average"] , bins = bins_num);

# %%
plt.hist(df["vote_average"] , facecolor='g' , edgecolor ='red' );
plt.xlabel("Vote Average")
plt.ylabel("Frequancy")
plt.title("Distribution of Vote Average")
plt.show()

# %%
#Line chart  x              y
plt.plot([10,20,30,40],[1,2,3,4])
plt.plot([10,20,30,40],[11,12,31,41])

# %%
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
movie_count = pd.DataFrame(df.release_year.value_counts(ascending=True))
movie_count
# Out:
#               count
# release_year
# 2003.0           19
# 1977.0           57
# 1994.0          184
# 1999.0          224
# 2001.0          242
# 2002.0          266
# 2010.0          490
# 2008.0          496
# 2009.0          533
# 2011.0          540
# 2012.0          588
# 2015.0          629
# 2014.0          700

# %%
movie_count = movie_count.reset_index() # new index
movie_count
# Out:
#     index  release_year  count
# 0       0        2003.0     19
# 1       1        1977.0     57
# 2       2        1994.0    184
# 3       3        1999.0    224
# 4       4        2001.0    242
# 5       5        2002.0    266
# 6       6        2010.0    490
# 7       7        2008.0    496
# 8       8        2009.0    533
# 9       9        2011.0    540
# 10     10        2012.0    588
# 11     11        2015.0    629
# 12     12        2014.0    700

# %%
# CHANGE NAMEcOLUMS
movie_count = movie_count.sort_values(by = ['release_year'])
movie_count
# Out:
#     index  release_year  count
# 1       1        1977.0     57
# 2       2        1994.0    184
# 3       3        1999.0    224
# 4       4        2001.0    242
# 5       5        2002.0    266
# 0       0        2003.0     19
# 7       7        2008.0    496
# 8       8        2009.0    533
# 6       6        2010.0    490
# 9       9        2011.0    540
# 10     10        2012.0    588
# 12     12        2014.0    700
# 11     11        2015.0    629

# %%
plt.plot(movie_count['release_year'] , movie_count['count'] ,c='0.6');

# %%
plt.plot(movie_count['release_year'] , movie_count['count'] ,c='0.6');
plt.xlabel ("Year")
plt.ylabel("Count")
plt.title("Film Year")
plt.show()

# %%
plt.plot(movie_count['release_year'] , movie_count['count'] ,c='0.6');
plt.xlabel ("Year")
plt.ylabel("Count")
plt.title("Film Year")
plt.xlim(1977,2015)
# Out:
# (1977.0, 2015.0)

# %%
# Bar Chart
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
top_revenue = df.groupby('original_title').sum().sort_values(by="revenue" ,ascending = False)
top_revenue.head()
# Out:
#                                   id    imdb_id  popularity     budget  \
# original_title
# Avatar                         19995  tt0499549    9.432768  237000000
# Star Wars: The Force Awakens  140607  tt2488496   11.173104  200000000
# The Avengers                   24428  tt0848228    7.637767  220000000
# Jurassic World                135397  tt0369610   32.985763  150000000
# Furious 7                     168259  tt2820852    9.335014  190000000
#
#                                  revenue  \
# original_title
# Avatar                        2781505847
# Star Wars: The Force Awakens  2068178225
# The Avengers                  1519557910
# Jurassic World                1513528810
# Furious 7                     1506249360
#
#                                                                            cast  \
# original_title
# Avatar                        Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# ...

# %%
movies = top_revenue.head().index
revenue = top_revenue.head().revenue.values
revenue
# Out:
# array([2781505847, 2068178225, 1519557910, 1513528810, 1506249360])

# %%
plt.bar(movies , revenue);

# %%
#pie chart
top_genres = df.groupby('genres').sum().sort_values(by =  'budget' , ascending = False)['budget'][0:5]
top_genres
# Out:
# genres
# Comedy                  3566056394
# Drama                   2820178701
# Comedy|Romance          1747050002
# Comedy|Drama|Romance    1294752716
# Drama|Romance           1245815060
# Name: budget, dtype: int64

# %%
plt.pie(top_genres.values , labels = top_genres.index);

# %%
# scatter chart
df.head(2)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
#
#                         homepage         director             tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow   The park is open.  ...
# 1    http://www.madmaxmovie.com/    George Miller  What a Lovely Day.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
#
# ...

# %%
plt.scatter(df.vote_average,df.revenue , alpha = 0.2);
plt.scatter(df.vote_count,df.revenue , alpha = 0.6);
plt.xlabel("Vote Average")
plt.ylabel("revenue")
plt.title("Scatter Chart")
plt.show()
